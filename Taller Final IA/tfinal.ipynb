# %% [markdown]
# # Taller Final de Inteligencia Artificial
# Antonio Elias Sánchez Soto
#
# BDFC 301

# %% [markdown]
# ## Contexto
# Según la Organización Mundial de la Salud (OMS), el accidente cerebrovascular es la segunda causa principal de muerte a nivel mundial, responsable de aproximadamente el 11% del total de muertes.
#
# Este conjunto de datos se utiliza para predecir si un paciente tiene probabilidades de sufrir un accidente cerebrovascular basándose en parámetros de entrada como género, edad, diversas enfermedades y estado de fumador. Cada fila en los datos proporciona información relevante sobre el paciente.
#
# Información de los atributos:
# - id: identificador único
# - gender: "Male" (Masculino), "Female" (Femenino) u "Other" (Otro)
# - age: edad del paciente
# - hypertension: 0 si el paciente no tiene hipertensión, 1 si tiene hipertensión
# - heart_disease: 0 si el paciente no tiene enfermedades cardíacas, 1 si tiene una enfermedad cardíaca
# - ever_married: "No" o "Yes" (Si ha estado casado alguna vez)
# - work_type: "children" (niños), "Govt_job" (trabajo gubernamental), "Never_worked" (nunca ha trabajado), "Private" (privado) o "Self-employed" (autónomo)
# - Residence_type: "Rural" o "Urban" (Urbano)
# - avg_glucose_level: nivel promedio de glucosa en sangre
# - bmi: índice de masa corporal
# - smoking_status: "formerly smoked" (ex fumador), "never smoked" (nunca ha fumado), "smokes" (fuma) o "Unknown"* (Desconocido)
# - stroke: 1 si el paciente tuvo un accidente cerebrovascular o 0 si no
#
# *Nota: "Unknown" en smoking_status significa que la información no está disponible para este paciente

# %% [markdown]
# ## Carga del Dataset
# En esta sección se realiza la inspección inicial del dataset para entender la estructura de los datos.

# %% [markdown]
# El primer paso es importar las librerías necesarias.
# - Pandas está diseñado para la manipulación y análisis de datos contenidos en DataFrames.
# - Matplotlib permite crear gráficos estáticos, animado e interactivos.
# - Seaborn facilita la creación de gráficos complejos con código menos complejos que Matplotlib (en algunos casos).

# %%
# importar librerias
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#carga del dataset
df=pd.read_csv('healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape # cantidad de filas y columnas
# Out:
# (5110, 12)

# %%
#información acerca de los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# Conocemos que existen 5110 elementos en el conjunto, de estos solo 4909 poseen un valor en la característica de bmi (índice de masa corporal). Este podría ser un dato valioso por su afinidad con las enfermedades cerebrovasculares, por tanto, durante el preprocesamiento será necesario imputar aquellas filas sin dicha característica.

# %%
df['age'] = df['age'].astype(int)

# %%
df.describe() #información referente a variables estadísticas como media, varianza, entre otros.
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.215264      0.097456       0.054012
# std    21161.721625    22.633866      0.296607       0.226063
# min       67.000000     0.000000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# ### Conteo por categorías
#
# Algunas de las características presentes para cada individuo en el dataset hacen referencia a valores categoriales, no solo los de tipo objeto, también algunos de tipo int.
#
# El conteo por cada categoría de estas características es el siguiente.

# %%
df['gender'].value_counts(normalize=True) #  el género other se puede asumir como falta de datos por lo que se podrían imputar estos valores
# Out:
# gender
# Female    0.585910
# Male      0.413894
# Other     0.000196
# Name: proportion, dtype: float64

# %%
df = df[df['gender'] != 'Other']

# %%
df['hypertension'].value_counts(normalize=True)
# Out:
# hypertension
# 0    0.902525
# 1    0.097475
# Name: proportion, dtype: float64

# %%
df['heart_disease'].value_counts(normalize=True)
# Out:
# heart_disease
# 0    0.945978
# 1    0.054022
# Name: proportion, dtype: float64

# %%
df['ever_married'].value_counts(normalize=True)
# Out:
# ever_married
# Yes    0.656293
# No     0.343707
# Name: proportion, dtype: float64

# %%
df['work_type'].value_counts(normalize=True)
# Out:
# work_type
# Private          0.572323
# Self-employed    0.160305
# children         0.134469
# Govt_job         0.128597
# Never_worked     0.004306
# Name: proportion, dtype: float64

# %%
df['Residence_type'].value_counts(normalize=True)
# Out:
# Residence_type
# Urban    0.508123
# Rural    0.491877
# Name: proportion, dtype: float64

# %%
df['smoking_status'].value_counts(normalize=True)# el estado de unknown o desconocido para el caso de fumadores es falta de información, por lo que se podría inducir según la edad, los niños nunca han fumado, el resto se imputaría
# Out:
# smoking_status
# never smoked       0.370327
# Unknown            0.302212
# formerly smoked    0.173028
# smokes             0.154433
# Name: proportion, dtype: float64

# %%
# Reemplazar 'Unknown' por 'never smoked' si son niños (edad < 18)
df.loc[(df['smoking_status'] == 'Unknown') & (df['age'] < 18), 'smoking_status'] = 'never smoked'

# Eliminar filas donde smoking_status es 'Unknown' y edad >= 18
df = df[df['smoking_status'] != 'Unknown']

# %%
df['stroke'].value_counts(normalize=True)
# Out:
# stroke
# 0    0.951966
# 1    0.048034
# Name: proportion, dtype: float64

# %%
df=df.dropna() # eliminar nulos
df=df.drop_duplicates() #eliminar duplicados

# %% [markdown]
# ## Análisis exploratorio
#
# ### Categoriales
#
# Se puede partir con la exploración de los datos categoriales referidos en el dataset. Con los resultados del análisis anterior se tiene una idea de como serían las proporciones en el gráfico.

# %%
df=df.drop(columns=['id'])
df.shape
# Out:
# (4091, 11)

# %%
categorical = df.select_dtypes(include = ["int64","object"]).columns

for col in categorical :
    plt.figure(figsize=(8,6))
    sns.displot(data = df[col], color = "orange")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.title(f"Histogram of {col}")
    plt.show()

# %% [markdown]
# ### Datos numéricos
#
# Asociados a valores continuos referentes a la edad, el nivel promedio de glucosa en sangre e índice de masa corporal.

# %%
numeric_cols = df.select_dtypes(include = ["float64"]).columns

for col in numeric_cols :
    plt.figure(figsize=(8,6))
    sns.displot(data = df[col], kde = True , color = "orange")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
numeric_cols = df.select_dtypes(include = ["float"]).columns

for col in numeric_cols :
    plt.figure(figsize=(8,6))
    sns.boxplot(data = df[col] , orient = "h" , color = "orange")
    plt.ylabel(col)
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ### Análisis Bivariado

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(data = df , x = "avg_glucose_level" , y = "bmi" , hue = "gender")
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='bmi'>

# %%
sns.scatterplot(data = df , x = "avg_glucose_level" , y = "bmi" , hue = "smoking_status")
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='bmi'>

# %%
sns.scatterplot(data = df , x = "avg_glucose_level" , y = "bmi" , hue = "stroke")
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='bmi'>

# %% [markdown]
# ## Preprocesamiento

# %%
veri = df.copy()

# %%
#one hot encoding
selected_cols = veri[["gender" , "ever_married" , "work_type" , "Residence_type" , "smoking_status"]]
selected_cols = pd.get_dummies(selected_cols)
selected_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4091 entries, 0 to 5108
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender_Female                   4091 non-null   bool
#  1   gender_Male                     4091 non-null   bool
#  2   ever_married_No                 4091 non-null   bool
#  3   ever_married_Yes                4091 non-null   bool
#  4   work_type_Govt_job              4091 non-null   bool
#  5   work_type_Never_worked          4091 non-null   bool
#  6   work_type_Private               4091 non-null   bool
#  7   work_type_Self-employed         4091 non-null   bool
#  8   work_type_children              4091 non-null   bool
#  9   Residence_type_Rural            4091 non-null   bool
#  10  Residence_type_Urban            4091 non-null   bool
#  11  smoking_status_formerly smoked  4091 non-null   bool
#  12  smoking_status_never smoked     4091 non-null   bool
#  13  smoking_status_smokes           4091 non-null   bool
# dtypes: bool(14)
# memory usage: 87.9 KB

# %%
veri = veri.drop(columns = ["gender" ,"ever_married" , "work_type" , "Residence_type" , "smoking_status"])
veri = pd.concat ([selected_cols,veri] , axis = 1)
veri.reset_index(drop=True, inplace=True)
veri
# Out:
#       gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# 0             False         True            False              True
# 1             False         True            False              True
# 2              True        False            False              True
# 3              True        False            False              True
# 4             False         True            False              True
# ...             ...          ...              ...               ...
# 4086           True        False            False              True
# 4087           True        False             True             False
# 4088           True        False            False              True
# 4089           True        False            False              True
# 4090          False         True            False              True
#
#       work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# 0                  False                   False               True
# 1                  False                   False               True
# 2                  False                   False               True
# 3                  False                   False              False
# 4                  False                   False               True
# ...                  ...                     ...                ...
# 4086               False                   False               True
# 4087               False                   False              False
# 4088               False                   False              False
# 4089               False                   False              False
# 4090               False                   False               True
#
#       work_type_Self-employed  work_type_children  Residence_type_Rural  \
# 0                       False               False                 False
# 1                       False               False                  True
# 2                       False               False                 False
# 3                        True               False                  True
# 4                       False               False                 False
# ...                       ...                 ...                   ...
# 4086                    False               False                  True
# 4087                    False                True                  True
# 4088                     True               False                 False
# 4089                     True               False                  True
# 4090                    False               False                  True
#
#       Residence_type_Urban  smoking_status_formerly smoked  \
# 0                     True                            True
# 1                    False                           False
# 2                     True                           False
# 3                    False                           False
# 4                     True                            True
# ...                    ...                             ...
# 4086                 False                           False
# 4087                 False                           False
# 4088                  True                           False
# 4089                 False                           False
# 4090                 False                            True
#
#       smoking_status_never smoked  smoking_status_smokes  age  hypertension  \
# 0                           False                  False   67             0
# 1                            True                  False   80             0
# 2                           False                   True   49             0
# 3                            True                  False   79             1
# 4                           False                  False   81             0
# ...                           ...                    ...  ...           ...
# 4086                         True                  False   57             0
# 4087                         True                  False   13             0
# 4088                         True                  False   81             0
# 4089                         True                  False   35             0
# 4090                        False                  False   51             0
#
#       heart_disease  avg_glucose_level   bmi  stroke
# 0                 1             228.69  36.6       1
# 1                 1             105.92  32.5       1
# 2                 0             171.23  34.4       1
# 3                 0             174.12  24.0       1
# 4                 0             186.21  29.0       1
# ...             ...                ...   ...     ...
# 4086              0              77.93  21.7       0
# 4087              0             103.08  18.6       0
# 4088              0             125.20  40.0       0
# 4089              0              82.99  30.6       0
# 4090              0             166.29  25.6       0
#
# [4091 rows x 20 columns]

# %%
from sklearn.preprocessing import StandardScaler
# estandarizacion variables numericas
numeric_cols = ['avg_glucose_level', 'bmi']
scaler=StandardScaler()
veri[numeric_cols]=scaler.fit_transform(veri[numeric_cols])
veri.head()
# Out:
#    gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# 0          False         True            False              True
# 1          False         True            False              True
# 2           True        False            False              True
# 3           True        False            False              True
# 4          False         True            False              True
#
#    work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# 0               False                   False               True
# 1               False                   False               True
# 2               False                   False               True
# 3               False                   False              False
# 4               False                   False               True
#
#    work_type_Self-employed  work_type_children  Residence_type_Rural  \
# 0                    False               False                 False
# 1                    False               False                  True
# 2                    False               False                 False
# 3                     True               False                  True
# 4                    False               False                 False
#
#    Residence_type_Urban  smoking_status_formerly smoked  \
# 0                  True                            True
# 1                 False                           False
# 2                  True                           False
# 3                 False                           False
# 4                  True                            True
#
#    smoking_status_never smoked  smoking_status_smokes  age  hypertension  \
# 0                        False                  False   67             0
# 1                         True                  False   80             0
# 2                        False                   True   49             0
# 3                         True                  False   79             1
# 4                        False                  False   81             0
#
#    heart_disease  avg_glucose_level       bmi  stroke
# 0              1           2.723373  0.998360       1
# 1              1           0.002793  0.482357       1
# 2              0           1.450061  0.721480       1
# 3              0           1.514103 -0.587406       1
# 4              0           1.782017  0.041866       1

# %%
correlation = veri.corr()
correlation
# Out:
#                                 gender_Female  gender_Male  ever_married_No  \
# gender_Female                        1.000000    -1.000000        -0.044749
# gender_Male                         -1.000000     1.000000         0.044749
# ever_married_No                     -0.044749     0.044749         1.000000
# ever_married_Yes                     0.044749    -0.044749        -1.000000
# work_type_Govt_job                   0.007341    -0.007341        -0.147128
# work_type_Never_worked              -0.019560     0.019560         0.092509
# work_type_Private                    0.051034    -0.051034        -0.199517
# work_type_Self-employed              0.028531    -0.028531        -0.206329
# work_type_children                  -0.099409     0.099409         0.584611
# Residence_type_Rural                -0.005199     0.005199         0.009734
# Residence_type_Urban                 0.005199    -0.005199        -0.009734
# smoking_status_formerly smoked      -0.040703     0.040703        -0.213961
# smoking_status_never smoked          0.041805    -0.041805         0.283598
# smoking_status_smokes               -0.010212     0.010212        -0.134498
# age                                  0.036105    -0.036105        -0.701969
# hypertension                        -0.020262     0.020262        -0.178034
# heart_disease                       -0.082888     0.082888        -0.119308
# avg_glucose_level                   -0.051571     0.051571        -0.167263
# bmi                                  0.033536    -0.033536        -0.375832
# stroke                              -0.000766     0.000766        -0.111157
#
#                                 ever_married_Yes  work_type_Govt_job  \
# gender_Female                           0.044749            0.007341
# gender_Male                            -0.044749           -0.007341
# ever_married_No                        -1.000000           -0.147128
# ever_married_Yes                        1.000000            0.147128
# work_type_Govt_job                      0.147128            1.000000
# work_type_Never_worked                 -0.092509           -0.026629
# work_type_Private                       0.199517           -0.419380
# work_type_Self-employed                 0.206329           -0.163153
# work_type_children                     -0.584611           -0.168281
# Residence_type_Rural                   -0.009734           -0.009792
# Residence_type_Urban                    0.009734            0.009792
# smoking_status_formerly smoked          0.213961            0.037532
# smoking_status_never smoked            -0.283598           -0.061442
# smoking_status_smokes                   0.134498            0.038396
# age                                     0.701969            0.146705
# hypertension                            0.178034            0.030467
# heart_disease                           0.119308            0.009712
# avg_glucose_level                       0.167263            0.026555
# bmi                                     0.375832            0.095281
# stroke                                  0.111157            0.000610
#
#                                 work_type_Never_worked  work_type_Private  \
# gender_Female                                -0.019560           0.051034
# gender_Male                                   0.019560          -0.051034
# ever_married_No                               0.092509          -0.199517
# ever_married_Yes                             -0.092509           0.199517
# work_type_Govt_job                           -0.026629          -0.419380
# work_type_Never_worked                        1.000000          -0.077372
# work_type_Private                            -0.077372           1.000000
# work_type_Self-employed                      -0.030100          -0.474056
# work_type_children                           -0.031047          -0.488955
# Residence_type_Rural                         -0.019848           0.013216
# Residence_type_Urban                          0.019848          -0.013216
# smoking_status_formerly smoked               -0.035522           0.050955
# smoking_status_never smoked                   0.055399          -0.146451
# smoking_status_smokes                        -0.032856           0.131920
# age                                          -0.078235           0.169449
# hypertension                                 -0.023361           0.012045
# heart_disease                                -0.016181           0.025338
# avg_glucose_level                            -0.014208           0.009770
# bmi                                          -0.024500           0.233691
# stroke                                       -0.015080           0.022899
#
#                                 work_type_Self-employed  work_type_children  \
# gender_Female                                  0.028531           -0.099409
# gender_Male                                   -0.028531            0.099409
# ever_married_No                               -0.206329            0.584611
# ever_married_Yes                               0.206329           -0.584611
# work_type_Govt_job                            -0.163153           -0.168281
# work_type_Never_worked                        -0.030100           -0.031047
# work_type_Private                             -0.474056           -0.488955
# work_type_Self-employed                        1.000000           -0.190220
# work_type_children                            -0.190220            1.000000
# Residence_type_Rural                          -0.009612            0.004171
# Residence_type_Urban                           0.009612           -0.004171
# smoking_status_formerly smoked                 0.111733           -0.204834
# smoking_status_never smoked                   -0.091564            0.331097
# smoking_status_smokes                         -0.001327           -0.204200
# age                                            0.332692           -0.670248
# hypertension                                   0.110836           -0.147628
# heart_disease                                  0.060806           -0.099245
# avg_glucose_level                              0.083140           -0.115669
# bmi                                            0.088063           -0.481054
# stroke                                         0.064969           -0.092091
#
#                                 Residence_type_Rural  Residence_type_Urban  \
# gender_Female                              -0.005199              0.005199
# gender_Male                                 0.005199             -0.005199
# ever_married_No                             0.009734             -0.009734
# ever_married_Yes                           -0.009734              0.009734
# work_type_Govt_job                         -0.009792              0.009792
# work_type_Never_worked                     -0.019848              0.019848
# work_type_Private                           0.013216             -0.013216
# work_type_Self-employed                    -0.009612              0.009612
# work_type_children                          0.004171             -0.004171
# Residence_type_Rural                        1.000000             -1.000000
# Residence_type_Urban                       -1.000000              1.000000
# smoking_status_formerly smoked             -0.006002              0.006002
# smoking_status_never smoked                 0.031393             -0.031393
# smoking_status_smokes                      -0.033441              0.033441
# age                                        -0.012731              0.012731
# hypertension                                0.003177             -0.003177
# heart_disease                              -0.010606              0.010606
# avg_glucose_level                           0.011180             -0.011180
# bmi                                         0.005801             -0.005801
# stroke                                     -0.004693              0.004693
#
#                                 smoking_status_formerly smoked  \
# gender_Female                                        -0.040703
# gender_Male                                           0.040703
# ever_married_No                                      -0.213961
# ever_married_Yes                                      0.213961
# work_type_Govt_job                                    0.037532
# work_type_Never_worked                               -0.035522
# work_type_Private                                     0.050955
# work_type_Self-employed                               0.111733
# work_type_children                                   -0.204834
# Residence_type_Rural                                 -0.006002
# Residence_type_Urban                                  0.006002
# smoking_status_formerly smoked                        1.000000
# smoking_status_never smoked                          -0.641197
# smoking_status_smokes                                -0.237564
# age                                                   0.285902
# hypertension                                          0.053393
# heart_disease                                         0.076612
# avg_glucose_level                                     0.075795
# bmi                                                   0.133293
# stroke                                                0.058996
#
#                                 smoking_status_never smoked  \
# gender_Female                                      0.041805
# gender_Male                                       -0.041805
# ever_married_No                                    0.283598
# ever_married_Yes                                  -0.283598
# work_type_Govt_job                                -0.061442
# work_type_Never_worked                             0.055399
# work_type_Private                                 -0.146451
# work_type_Self-employed                           -0.091564
# work_type_children                                 0.331097
# Residence_type_Rural                               0.031393
# Residence_type_Urban                              -0.031393
# smoking_status_formerly smoked                    -0.641197
# smoking_status_never smoked                        1.000000
# smoking_status_smokes                             -0.593083
# age                                               -0.318561
# hypertension                                      -0.058189
# heart_disease                                     -0.104099
# avg_glucose_level                                 -0.068337
# bmi                                               -0.197926
# stroke                                            -0.064520
#
#                                 smoking_status_smokes       age  hypertension  \
# gender_Female                               -0.010212  0.036105     -0.020262
# gender_Male                                  0.010212 -0.036105      0.020262
# ever_married_No                             -0.134498 -0.701969     -0.178034
# ever_married_Yes                             0.134498  0.701969      0.178034
# work_type_Govt_job                           0.038396  0.146705      0.030467
# work_type_Never_worked                      -0.032856 -0.078235     -0.023361
# work_type_Private                            0.131920  0.169449      0.012045
# work_type_Self-employed                     -0.001327  0.332692      0.110836
# work_type_children                          -0.204200 -0.670248     -0.147628
# Residence_type_Rural                        -0.033441 -0.012731      0.003177
# Residence_type_Urban                         0.033441  0.012731     -0.003177
# smoking_status_formerly smoked              -0.237564  0.285902      0.053393
# smoking_status_never smoked                 -0.593083 -0.318561     -0.058189
# smoking_status_smokes                        1.000000  0.103274      0.017637
# age                                          0.103274  1.000000      0.292519
# hypertension                                 0.017637  0.292519      1.000000
# heart_disease                                0.051389  0.257213      0.123826
# avg_glucose_level                            0.006978  0.251285      0.179037
# bmi                                          0.110689  0.366944      0.185080
# stroke                                       0.019773  0.240150      0.154169
#
#                                 heart_disease  avg_glucose_level       bmi  \
# gender_Female                       -0.082888          -0.051571  0.033536
# gender_Male                          0.082888           0.051571 -0.033536
# ever_married_No                     -0.119308          -0.167263 -0.375832
# ever_married_Yes                     0.119308           0.167263  0.375832
# work_type_Govt_job                   0.009712           0.026555  0.095281
# work_type_Never_worked              -0.016181          -0.014208 -0.024500
# work_type_Private                    0.025338           0.009770  0.233691
# work_type_Self-employed              0.060806           0.083140  0.088063
# work_type_children                  -0.099245          -0.115669 -0.481054
# Residence_type_Rural                -0.010606           0.011180  0.005801
# Residence_type_Urban                 0.010606          -0.011180 -0.005801
# smoking_status_formerly smoked       0.076612           0.075795  0.133293
# smoking_status_never smoked         -0.104099          -0.068337 -0.197926
# smoking_status_smokes                0.051389           0.006978  0.110689
# age                                  0.257213           0.251285  0.366944
# hypertension                         0.123826           0.179037  0.185080
# heart_disease                        1.000000           0.149179  0.048096
# avg_glucose_level                    0.149179           1.000000  0.184218
# bmi                                  0.048096           0.184218  1.000000
# stroke                               0.145575           0.145612  0.053769
#
#                                   stroke
# gender_Female                  -0.000766
# gender_Male                     0.000766
# ever_married_No                -0.111157
# ever_married_Yes                0.111157
# work_type_Govt_job              0.000610
# work_type_Never_worked         -0.015080
# work_type_Private               0.022899
# work_type_Self-employed         0.064969
# work_type_children             -0.092091
# Residence_type_Rural           -0.004693
# Residence_type_Urban            0.004693
# smoking_status_formerly smoked  0.058996
# smoking_status_never smoked    -0.064520
# smoking_status_smokes           0.019773
# age                             0.240150
# hypertension                    0.154169
# heart_disease                   0.145575
# avg_glucose_level               0.145612
# bmi                             0.053769
# stroke                          1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation , cmap="coolwarm", linewidths = 0.5)
plt.title('Matriz de correlación')
plt.show()

# %% [markdown]
# ## Selección de atributos

# %%
# Aplicar seleccion según correlación
correlationTarget=abs(correlation['stroke'])
relevantFeatures=correlationTarget[correlationTarget>0.1]
print("Atributos relevantes basados en la correlación con el stroke o variable objetivo:")
print(relevantFeatures)
# Out:
# Atributos relevantes basados en la correlación con el stroke o variable objetivo:
# ever_married_No      0.111157
# ever_married_Yes     0.111157
# age                  0.240150
# hypertension         0.154169
# heart_disease        0.145575
# avg_glucose_level    0.145612
# stroke               1.000000
# Name: stroke, dtype: float64

# %%
# Ganancia de información
from sklearn.feature_selection import mutual_info_classif

# calculo de ganancia de info de cada atributo
X=veri.drop(columns=['stroke'])
y=veri['stroke']
infoGain=mutual_info_classif(X,y)

# Dataframe 
infoGainDF=pd.DataFrame({"Feature":X.columns, "InfoGain":infoGain})
infoGainDF=infoGainDF.sort_values(by="InfoGain",ascending=False)
print('Atributos ordenados por Ganancia de Informacion')
print(infoGainDF)
# Out:
# Atributos ordenados por Ganancia de Informacion
#                            Feature  InfoGain
# 14                             age  0.033738
# 3                 ever_married_Yes  0.009845
# 2                  ever_married_No  0.008867
# 8               work_type_children  0.008852
# 17               avg_glucose_level  0.005739
# 16                   heart_disease  0.005429
# 9             Residence_type_Rural  0.004917
# 15                    hypertension  0.004489
# 12     smoking_status_never smoked  0.003978
# 18                             bmi  0.003771
# 6                work_type_Private  0.002290
# 7          work_type_Self-employed  0.002045
# 1                      gender_Male  0.000550
# 4               work_type_Govt_job  0.000513
# 0                    gender_Female  0.000288
# 10            Residence_type_Urban  0.000000
# 5           work_type_Never_worked  0.000000
# 13           smoking_status_smokes  0.000000
# 11  smoking_status_formerly smoked  0.000000

# %%
# Basado en consistencia
from sklearn.feature_selection import SelectKBest, f_classif

# Seleccionar los 6 mejores atributos basados en su consistencia con la clase
selector=SelectKBest(score_func=f_classif,k=6)
selector.fit(X,y)
consistentFeatures=X.columns[selector.get_support()]
print("Atributos por consistencia")
print(consistentFeatures)
# Out:
# Atributos por consistencia
# Index(['ever_married_No', 'ever_married_Yes', 'age', 'hypertension',
#        'heart_disease', 'avg_glucose_level'],
#       dtype='object')

# %%
# Comparacion y seleccion general
selectedFeatures=set(relevantFeatures.index).intersection(consistentFeatures).intersection(infoGainDF["Feature"])
print("Atributos seleccionados en comun por los tres metodos")
print(selectedFeatures)
# Out:
# Atributos seleccionados en comun por los tres metodos
# {'ever_married_No', 'avg_glucose_level', 'ever_married_Yes', 'hypertension', 'age', 'heart_disease'}

# %%
#subconjunto del DataFrame con caracteristicas seleccionadas
selectedDF=veri[list(selectedFeatures)+['stroke']]

#calcular matriz de correlacion para las caracteristicas
correlationMatrixSelected=selectedDF.corr()

# mapa de calor
plt.figure(figsize=(10,8))
sns.heatmap(correlationMatrixSelected,annot=True, cmap='viridis', fmt='.2f')
plt.title("Heatmap de las características más relevantes")
plt.show()

# %% [markdown]
# ## Red Neural

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, regularizers

# %%
model = keras.Sequential([
    layers.Input(shape=(len(selectedFeatures),)),
    layers.Dense(8, activation='relu'),
    layers.Dense(4, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Dividir los datos en conjunto de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedDF.drop('stroke', axis=1), selectedDF['stroke'], test_size=0.2, random_state=42)

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=40, validation_split=0.2)

# Guardar el modelo
model.save('stroke_prediction_model.keras')
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6066 - loss: 0.9478 - val_accuracy: 0.9634 - val_loss: 0.6655
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.6591 - val_accuracy: 0.9634 - val_loss: 0.6385
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9527 - loss: 0.6333 - val_accuracy: 0.9634 - val_loss: 0.6123
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9611 - loss: 0.6064 - val_accuracy: 0.9634 - val_loss: 0.5873
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.5839 - val_accuracy: 0.9634 - val_loss: 0.5635
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.5588 - val_accuracy: 0.9634 - val_loss: 0.5410
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9530 - loss: 0.5395 - val_accuracy: 0.9634 - val_loss: 0.5197
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.5182 - val_accuracy: 0.9634 - val_loss: 0.4996
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.4962 - val_accuracy: 0.9634 - val_loss: 0.4806
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9632 - loss: 0.4761 - val_accuracy: 0.9634 - val_loss: 0.4625
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9526 - loss: 0.4647 - val_accuracy: 0.9634 - val_loss: 0.4456
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9514 - loss: 0.4493 - val_accuracy: 0.9634 - val_loss: 0.4295
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.4272 - val_accuracy: 0.9634 - val_loss: 0.4143
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9548 - loss: 0.4172 - val_accuracy: 0.9634 - val_loss: 0.4001
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.3978 - val_accuracy: 0.9634 - val_loss: 0.3866
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.3891 - val_accuracy: 0.9634 - val_loss: 0.3739
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9634 - loss: 0.3708 - val_accuracy: 0.9634 - val_loss: 0.3619
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9565 - loss: 0.3656 - val_accuracy: 0.9634 - val_loss: 0.3506
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.3519 - val_accuracy: 0.9634 - val_loss: 0.3398
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.3422 - val_accuracy: 0.9634 - val_loss: 0.3298
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.3287 - val_accuracy: 0.9634 - val_loss: 0.3202
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.3138 - val_accuracy: 0.9634 - val_loss: 0.3112
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.3176 - val_accuracy: 0.9634 - val_loss: 0.3027
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.3074 - val_accuracy: 0.9634 - val_loss: 0.2947
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9562 - loss: 0.3019 - val_accuracy: 0.9634 - val_loss: 0.2871
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9549 - loss: 0.2964 - val_accuracy: 0.9634 - val_loss: 0.2800
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.2892 - val_accuracy: 0.9634 - val_loss: 0.2732
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.2770 - val_accuracy: 0.9634 - val_loss: 0.2667
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9610 - loss: 0.2686 - val_accuracy: 0.9634 - val_loss: 0.2607
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.2596 - val_accuracy: 0.9634 - val_loss: 0.2549
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9556 - loss: 0.2654 - val_accuracy: 0.9634 - val_loss: 0.2496
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.2502 - val_accuracy: 0.9634 - val_loss: 0.2444
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9587 - loss: 0.2507 - val_accuracy: 0.9634 - val_loss: 0.2397
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9638 - loss: 0.2378 - val_accuracy: 0.9634 - val_loss: 0.2350
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.2315 - val_accuracy: 0.9634 - val_loss: 0.2307
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.2274 - val_accuracy: 0.9634 - val_loss: 0.2266
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.2319 - val_accuracy: 0.9634 - val_loss: 0.2228
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.2266 - val_accuracy: 0.9634 - val_loss: 0.2190
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.2240 - val_accuracy: 0.9634 - val_loss: 0.2155
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9663 - loss: 0.2094 - val_accuracy: 0.9634 - val_loss: 0.2122
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.2212 - val_accuracy: 0.9634 - val_loss: 0.2092
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9488 - loss: 0.2361 - val_accuracy: 0.9634 - val_loss: 0.2063
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9559 - loss: 0.2200 - val_accuracy: 0.9634 - val_loss: 0.2034
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.2131 - val_accuracy: 0.9634 - val_loss: 0.2008
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9568 - loss: 0.2132 - val_accuracy: 0.9634 - val_loss: 0.1983
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.2038 - val_accuracy: 0.9634 - val_loss: 0.1959
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9558 - loss: 0.2109 - val_accuracy: 0.9634 - val_loss: 0.1936
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9631 - loss: 0.1936 - val_accuracy: 0.9634 - val_loss: 0.1915
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9668 - loss: 0.1838 - val_accuracy: 0.9634 - val_loss: 0.1894
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9562 - loss: 0.2044 - val_accuracy: 0.9634 - val_loss: 0.1876
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9591 - loss: 0.1964 - val_accuracy: 0.9634 - val_loss: 0.1858
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.1952 - val_accuracy: 0.9634 - val_loss: 0.1840
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9557 - loss: 0.2006 - val_accuracy: 0.9634 - val_loss: 0.1824
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.1909 - val_accuracy: 0.9634 - val_loss: 0.1810
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.1840 - val_accuracy: 0.9634 - val_loss: 0.1795
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1785 - val_accuracy: 0.9634 - val_loss: 0.1781
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.1746 - val_accuracy: 0.9634 - val_loss: 0.1769
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.1732 - val_accuracy: 0.9634 - val_loss: 0.1756
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9569 - loss: 0.1909 - val_accuracy: 0.9634 - val_loss: 0.1746
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.1903 - val_accuracy: 0.9634 - val_loss: 0.1734
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9544 - loss: 0.1949 - val_accuracy: 0.9634 - val_loss: 0.1724
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.1772 - val_accuracy: 0.9634 - val_loss: 0.1714
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9518 - loss: 0.1999 - val_accuracy: 0.9634 - val_loss: 0.1705
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9537 - loss: 0.1946 - val_accuracy: 0.9634 - val_loss: 0.1697
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.1877 - val_accuracy: 0.9634 - val_loss: 0.1688
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9580 - loss: 0.1822 - val_accuracy: 0.9634 - val_loss: 0.1681
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9604 - loss: 0.1754 - val_accuracy: 0.9634 - val_loss: 0.1674
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.1706 - val_accuracy: 0.9634 - val_loss: 0.1667
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9564 - loss: 0.1846 - val_accuracy: 0.9634 - val_loss: 0.1661
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9556 - loss: 0.1865 - val_accuracy: 0.9634 - val_loss: 0.1655
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.1751 - val_accuracy: 0.9634 - val_loss: 0.1649
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.1656 - val_accuracy: 0.9634 - val_loss: 0.1644
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.1810 - val_accuracy: 0.9634 - val_loss: 0.1639
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.1663 - val_accuracy: 0.9634 - val_loss: 0.1634
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9549 - loss: 0.1864 - val_accuracy: 0.9634 - val_loss: 0.1630
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.1798 - val_accuracy: 0.9634 - val_loss: 0.1626
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.1707 - val_accuracy: 0.9634 - val_loss: 0.1622
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1767 - val_accuracy: 0.9634 - val_loss: 0.1618
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.1842 - val_accuracy: 0.9634 - val_loss: 0.1615
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.1850 - val_accuracy: 0.9634 - val_loss: 0.1612
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.1756 - val_accuracy: 0.9634 - val_loss: 0.1609
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1897 - val_accuracy: 0.9634 - val_loss: 0.1607
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9593 - loss: 0.1722 - val_accuracy: 0.9634 - val_loss: 0.1604
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.1654 - val_accuracy: 0.9634 - val_loss: 0.1602
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9554 - loss: 0.1831 - val_accuracy: 0.9634 - val_loss: 0.1600
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9564 - loss: 0.1799 - val_accuracy: 0.9634 - val_loss: 0.1598
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9591 - loss: 0.1722 - val_accuracy: 0.9634 - val_loss: 0.1596
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.1728 - val_accuracy: 0.9634 - val_loss: 0.1594
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.1676 - val_accuracy: 0.9634 - val_loss: 0.1593
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9583 - loss: 0.1740 - val_accuracy: 0.9634 - val_loss: 0.1591
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9542 - loss: 0.1861 - val_accuracy: 0.9634 - val_loss: 0.1590
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9530 - loss: 0.1896 - val_accuracy: 0.9634 - val_loss: 0.1589
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.1701 - val_accuracy: 0.9634 - val_loss: 0.1587
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9585 - loss: 0.1732 - val_accuracy: 0.9634 - val_loss: 0.1586
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1804 - val_accuracy: 0.9634 - val_loss: 0.1586
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.1799 - val_accuracy: 0.9634 - val_loss: 0.1585
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.1772 - val_accuracy: 0.9634 - val_loss: 0.1584
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9580 - loss: 0.1746 - val_accuracy: 0.9634 - val_loss: 0.1583
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9542 - loss: 0.1860 - val_accuracy: 0.9634 - val_loss: 0.1582
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9595 - loss: 0.1699 - val_accuracy: 0.9634 - val_loss: 0.1582

# %% [markdown]
# ## Evaluación

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Predecir las etiquetas para el conjunto de prueba
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convertir probabilidades a etiquetas binarias

# Calcular métricas
conf_matrix = confusion_matrix(y_test, y_pred)

# Mostrar resultados
print('Matriz de Confusión:')
print(conf_matrix)

print('\nReporte de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Matriz de Confusión:
# [[770   0]
#  [ 49   0]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       770
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.94       819
#    macro avg       0.47      0.50      0.48       819
# weighted avg       0.88      0.94      0.91       819
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Uso de Dropout y L2

# %%
model = keras.Sequential([
    layers.Input(shape=(len(selectedFeatures),)),
    layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Penalización L2
    layers.Dropout(0.3),  # Aplicar Dropout con una tasa del 30%
    layers.Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Penalización L2
    layers.Dropout(0.3),  # Aplicar Dropout con una tasa del 30%
    layers.Dense(1, activation='sigmoid')
])

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Dividir los datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(selectedDF.drop('stroke', axis=1), selectedDF['stroke'], test_size=0.2, random_state=42)

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=40, validation_split=0.2)

# Guardar el modelo
model.save('stroke_prediction_model.keras')
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7846 - loss: 1.3475 - val_accuracy: 0.9618 - val_loss: 0.7671
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8310 - loss: 0.8873 - val_accuracy: 0.9634 - val_loss: 0.7192
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9171 - loss: 0.7585 - val_accuracy: 0.9634 - val_loss: 0.6773
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9227 - loss: 0.6870 - val_accuracy: 0.9634 - val_loss: 0.6398
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9212 - loss: 0.6457 - val_accuracy: 0.9634 - val_loss: 0.6065
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.5876 - val_accuracy: 0.9634 - val_loss: 0.5764
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9278 - loss: 0.5549 - val_accuracy: 0.9634 - val_loss: 0.5486
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.5246 - val_accuracy: 0.9634 - val_loss: 0.5240
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.4795 - val_accuracy: 0.9634 - val_loss: 0.5014
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9359 - loss: 0.4823 - val_accuracy: 0.9634 - val_loss: 0.4803
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9340 - loss: 0.4598 - val_accuracy: 0.9634 - val_loss: 0.4602
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9406 - loss: 0.4389 - val_accuracy: 0.9634 - val_loss: 0.4419
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9514 - loss: 0.4226 - val_accuracy: 0.9634 - val_loss: 0.4233
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9522 - loss: 0.4048 - val_accuracy: 0.9634 - val_loss: 0.4031
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9585 - loss: 0.3654 - val_accuracy: 0.9634 - val_loss: 0.3858
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9565 - loss: 0.3605 - val_accuracy: 0.9634 - val_loss: 0.3770
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9545 - loss: 0.3433 - val_accuracy: 0.9634 - val_loss: 0.3625
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9651 - loss: 0.3334 - val_accuracy: 0.9634 - val_loss: 0.3496
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.3312 - val_accuracy: 0.9634 - val_loss: 0.3370
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9558 - loss: 0.3208 - val_accuracy: 0.9634 - val_loss: 0.3251
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9584 - loss: 0.3199 - val_accuracy: 0.9634 - val_loss: 0.3168
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9585 - loss: 0.2962 - val_accuracy: 0.9634 - val_loss: 0.3063
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9593 - loss: 0.2926 - val_accuracy: 0.9634 - val_loss: 0.2960
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.2709 - val_accuracy: 0.9634 - val_loss: 0.2883
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9544 - loss: 0.2874 - val_accuracy: 0.9634 - val_loss: 0.2796
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9503 - loss: 0.2925 - val_accuracy: 0.9634 - val_loss: 0.2642
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.2682 - val_accuracy: 0.9634 - val_loss: 0.2605
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.2678 - val_accuracy: 0.9634 - val_loss: 0.2562
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9582 - loss: 0.2610 - val_accuracy: 0.9634 - val_loss: 0.2528
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9559 - loss: 0.2731 - val_accuracy: 0.9634 - val_loss: 0.2441
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.2348 - val_accuracy: 0.9634 - val_loss: 0.2347
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.2405 - val_accuracy: 0.9634 - val_loss: 0.2303
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.2333 - val_accuracy: 0.9634 - val_loss: 0.2230
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9656 - loss: 0.2350 - val_accuracy: 0.9634 - val_loss: 0.2174
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9606 - loss: 0.2278 - val_accuracy: 0.9634 - val_loss: 0.2075
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.2234 - val_accuracy: 0.9634 - val_loss: 0.1844
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.2042 - val_accuracy: 0.9634 - val_loss: 0.1661
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.2120 - val_accuracy: 0.9634 - val_loss: 0.1653
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9593 - loss: 0.2061 - val_accuracy: 0.9634 - val_loss: 0.1695
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.1944 - val_accuracy: 0.9634 - val_loss: 0.1621
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9555 - loss: 0.1987 - val_accuracy: 0.9634 - val_loss: 0.1605
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.1921 - val_accuracy: 0.9634 - val_loss: 0.1593
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9649 - loss: 0.1805 - val_accuracy: 0.9634 - val_loss: 0.1598
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9586 - loss: 0.1933 - val_accuracy: 0.9634 - val_loss: 0.1586
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9668 - loss: 0.1809 - val_accuracy: 0.9634 - val_loss: 0.1631
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9541 - loss: 0.2006 - val_accuracy: 0.9634 - val_loss: 0.1552
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.1797 - val_accuracy: 0.9634 - val_loss: 0.1548
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.1792 - val_accuracy: 0.9634 - val_loss: 0.1548
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9596 - loss: 0.1817 - val_accuracy: 0.9634 - val_loss: 0.1524
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.1780 - val_accuracy: 0.9634 - val_loss: 0.1507
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1723 - val_accuracy: 0.9634 - val_loss: 0.1501
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9536 - loss: 0.1890 - val_accuracy: 0.9634 - val_loss: 0.1498
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.1721 - val_accuracy: 0.9634 - val_loss: 0.1494
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9584 - loss: 0.1758 - val_accuracy: 0.9634 - val_loss: 0.1483
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.1677 - val_accuracy: 0.9634 - val_loss: 0.1496
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1627 - val_accuracy: 0.9634 - val_loss: 0.1491
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.1563 - val_accuracy: 0.9634 - val_loss: 0.1502
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.1663 - val_accuracy: 0.9634 - val_loss: 0.1473
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.1795 - val_accuracy: 0.9634 - val_loss: 0.1468
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9554 - loss: 0.1825 - val_accuracy: 0.9634 - val_loss: 0.1464
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9526 - loss: 0.1882 - val_accuracy: 0.9634 - val_loss: 0.1454
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.1721 - val_accuracy: 0.9634 - val_loss: 0.1450
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.1746 - val_accuracy: 0.9634 - val_loss: 0.1452
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9599 - loss: 0.1655 - val_accuracy: 0.9634 - val_loss: 0.1453
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.1777 - val_accuracy: 0.9634 - val_loss: 0.1453
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1604 - val_accuracy: 0.9634 - val_loss: 0.1444
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.1674 - val_accuracy: 0.9634 - val_loss: 0.1444
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9495 - loss: 0.1962 - val_accuracy: 0.9634 - val_loss: 0.1435
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.1741 - val_accuracy: 0.9634 - val_loss: 0.1449
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9590 - loss: 0.1687 - val_accuracy: 0.9634 - val_loss: 0.1433
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9537 - loss: 0.1798 - val_accuracy: 0.9634 - val_loss: 0.1452
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9598 - loss: 0.1695 - val_accuracy: 0.9634 - val_loss: 0.1439
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.1580 - val_accuracy: 0.9634 - val_loss: 0.1435
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9636 - loss: 0.1580 - val_accuracy: 0.9634 - val_loss: 0.1422
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.1659 - val_accuracy: 0.9634 - val_loss: 0.1436
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9609 - loss: 0.1612 - val_accuracy: 0.9634 - val_loss: 0.1455
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9573 - loss: 0.1711 - val_accuracy: 0.9634 - val_loss: 0.1438
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.1683 - val_accuracy: 0.9634 - val_loss: 0.1445
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1562 - val_accuracy: 0.9634 - val_loss: 0.1429
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.1681 - val_accuracy: 0.9634 - val_loss: 0.1434
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9563 - loss: 0.1710 - val_accuracy: 0.9634 - val_loss: 0.1404
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.1670 - val_accuracy: 0.9634 - val_loss: 0.1414
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.1692 - val_accuracy: 0.9634 - val_loss: 0.1408
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9534 - loss: 0.1916 - val_accuracy: 0.9634 - val_loss: 0.1424
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9561 - loss: 0.1799 - val_accuracy: 0.9634 - val_loss: 0.1420
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9586 - loss: 0.1672 - val_accuracy: 0.9634 - val_loss: 0.1434
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9514 - loss: 0.1825 - val_accuracy: 0.9634 - val_loss: 0.1408
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1605 - val_accuracy: 0.9634 - val_loss: 0.1441
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.1622 - val_accuracy: 0.9634 - val_loss: 0.1433
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.1646 - val_accuracy: 0.9634 - val_loss: 0.1436
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.1662 - val_accuracy: 0.9634 - val_loss: 0.1425
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9515 - loss: 0.1875 - val_accuracy: 0.9634 - val_loss: 0.1445
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1548 - val_accuracy: 0.9634 - val_loss: 0.1422
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9599 - loss: 0.1572 - val_accuracy: 0.9634 - val_loss: 0.1410
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.1585 - val_accuracy: 0.9634 - val_loss: 0.1432
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.1679 - val_accuracy: 0.9634 - val_loss: 0.1407
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9584 - loss: 0.1651 - val_accuracy: 0.9634 - val_loss: 0.1411
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9620 - loss: 0.1537 - val_accuracy: 0.9634 - val_loss: 0.1420
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9593 - loss: 0.1618 - val_accuracy: 0.9634 - val_loss: 0.1412
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9562 - loss: 0.1741 - val_accuracy: 0.9634 - val_loss: 0.1407

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, y_pred)

print('Matriz de Confusión:')
print(conf_matrix)
print('\nReporte de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Matriz de Confusión:
# [[770   0]
#  [ 49   0]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       770
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.94       819
#    macro avg       0.47      0.50      0.48       819
# weighted avg       0.88      0.94      0.91       819
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Coding\Laboratorios IA\entorno\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
